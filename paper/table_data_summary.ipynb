# %% [markdown]
# ## Data Summary: Field Coverage
#
# This notebook summarizes the availability of key fields (birthdate, deathdate, birthplace, nationality, etc.) across all individuals in the database.
# Each row shows how many individuals have a non-null value for that property, along with the percentage of the total population.

# %%
import sqlite3
import pandas as pd

DB = '../data/humans_clean.sqlite3'
conn = sqlite3.connect(DB)

queries = [
    ('Total individuals',            'SELECT COUNT(*) FROM individuals'),
    ('Date of birth',                'SELECT COUNT(*) FROM individuals WHERE birthdate IS NOT NULL'),
    ('Date of death',                'SELECT COUNT(*) FROM individuals WHERE deathdate IS NOT NULL'),
    ('Place of birth',               'SELECT COUNT(*) FROM individuals WHERE birthcity_en IS NOT NULL'),
    ('Place of death',               'SELECT COUNT(*) FROM individuals WHERE deathcity_en IS NOT NULL'),
    ('Nationality',                  'SELECT COUNT(*) FROM individuals WHERE nationalities_en IS NOT NULL'),
    ('Occupation',                   'SELECT COUNT(*) FROM individuals WHERE occupations_en IS NOT NULL'),
    ('Gender',                       'SELECT COUNT(*) FROM individuals WHERE gender IS NOT NULL'),
    ('Writing language',             'SELECT COUNT(*) FROM individuals WHERE writing_language_name_en IS NOT NULL'),
    ('Wikipedia sitelinks (>=1)',    'SELECT COUNT(*) FROM individuals WHERE sitelinks_count > 0'),
    ('External identifiers (>=1)',   'SELECT COUNT(*) FROM individuals WHERE identifiers_count > 0'),
    ('Impact date (computed)',       'SELECT COUNT(*) FROM individuals_impact_date'),
    ('Country mapping',              'SELECT COUNT(DISTINCT wikidata_id) FROM individuals_countries'),
    ('Region mapping',               'SELECT COUNT(DISTINCT wikidata_id) FROM individuals_regions'),
    ('Cliopatria polity mapping',    'SELECT COUNT(DISTINCT wikidata_id) FROM individuals_cliopatria'),
]

total = None
rows_data = []
for label, q in queries:
    count = conn.execute(q).fetchone()[0]
    if total is None:
        total = count
    rows_data.append({'Property': label, 'Individuals': f'{count:,}', '% of total': f'{100*count/total:.1f}'})

conn.close()

df = pd.DataFrame(rows_data)
df.style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_3ff09">
#   <thead>
#     <tr>
#       <th id="T_3ff09_level0_col0" class="col_heading level0 col0" >Property</th>
#       <th id="T_3ff09_level0_col1" class="col_heading level0 col1" >Individuals</th>
#       <th id="T_3ff09_level0_col2" class="col_heading level0 col2" >% of total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3ff09_row0_col0" class="data row0 col0" >Total individuals</td>
#       <td id="T_3ff09_row0_col1" class="data row0 col1" >13,002,897</td>
#       <td id="T_3ff09_row0_col2" class="data row0 col2" >100.0</td>
#     </tr>
#     <tr>
#       <td id="T_3ff09_row1_col0" class="data row1 col0" >Date of birth</td>
#       <td id="T_3ff09_row1_col1" class="data row1 col1" >7,511,293</td>
#       <td id="T_3ff09_row1_col2" class="data row1 col2" >57.8</td>
#     </tr>
#     <tr>
#       <td id="T_3ff09_row2_col0" class="data row2 col0" >Date of death</td>
#       <td id="T_3ff09_row2_col1" class="data row2 col1" >3,573,392</td>
#       <td id="T_3ff09_row2_col2" class="data row2 col2" >27.5</td>
#     </tr>
#     <tr>
#       <td id="T_3ff09_row3_col0" class="data row3 col0" >Place of birth</td>
#       <td id="T_3ff09_row3_col1" class="data row3 col1" >3,724,787</td>
#       <td id="T_3ff09_row3_col2" class="data row3 col2" >28.6</td>
#     </tr>
#     <tr>
#       <td id="T_3ff09_row4_col0" class="data row4 col0" >Place of death</td>
#       <td id="T_3ff09_row4_col1" class="data row4 col1" >1,585,483</td>
#       <td id="T_3ff09_row4_col2" class="data row4 col2" >12.2</td>
#     </tr>
#     <tr>
#       <td id="T_3ff09_row5_col0" class="data row5 col0" >Nationality</td>
#       <td id="T_3ff09_row5_col1" class="data row5 col1" >5,570,031</td>
#       <td id="T_3ff09_row5_col2" class="data row5 col2" >42.8</td>
#     </tr>
#     <tr>
#       <td id="T_3ff09_row6_col0" class="data row6 col0" >Occupation</td>
#       <td id="T_3ff09_row6_col1" class="data row6 col1" >9,032,161</td>
#       <td id="T_3ff09_row6_col2" class="data row6 col2" >69.5</td>
#     </tr>
#     <tr>
#       <td id="T_3ff09_row7_col0" class="data row7 col0" >Gender</td>
#       <td id="T_3ff09_row7_col1" class="data row7 col1" >8,953,963</td>
#       <td id="T_3ff09_row7_col2" class="data row7 col2" >68.9</td>
#     </tr>
#     <tr>
#       <td id="T_3ff09_row8_col0" class="data row8 col0" >Writing language</td>
#       <td id="T_3ff09_row8_col1" class="data row8 col1" >225,825</td>
#       <td id="T_3ff09_row8_col2" class="data row8 col2" >1.7</td>
#     </tr>
#     <tr>
#       <td id="T_3ff09_row9_col0" class="data row9 col0" >Wikipedia sitelinks (>=1)</td>
#       <td id="T_3ff09_row9_col1" class="data row9 col1" >4,959,581</td>
#       <td id="T_3ff09_row9_col2" class="data row9 col2" >38.1</td>
#     </tr>
#     <tr>
#       <td id="T_3ff09_row10_col0" class="data row10 col0" >External identifiers (>=1)</td>
#       <td id="T_3ff09_row10_col1" class="data row10 col1" >6,850,657</td>
#       <td id="T_3ff09_row10_col2" class="data row10 col2" >52.7</td>
#     </tr>
#     <tr>
#       <td id="T_3ff09_row11_col0" class="data row11 col0" >Impact date (computed)</td>
#       <td id="T_3ff09_row11_col1" class="data row11 col1" >7,749,380</td>
#       <td id="T_3ff09_row11_col2" class="data row11 col2" >59.6</td>
#     </tr>
#     <tr>
#       <td id="T_3ff09_row12_col0" class="data row12 col0" >Country mapping</td>
#       <td id="T_3ff09_row12_col1" class="data row12 col1" >6,374,506</td>
#       <td id="T_3ff09_row12_col2" class="data row12 col2" >49.0</td>
#     </tr>
#     <tr>
#       <td id="T_3ff09_row13_col0" class="data row13 col0" >Region mapping</td>
#       <td id="T_3ff09_row13_col1" class="data row13 col1" >5,319,038</td>
#       <td id="T_3ff09_row13_col2" class="data row13 col2" >40.9</td>
#     </tr>
#     <tr>
#       <td id="T_3ff09_row14_col0" class="data row14 col0" >Cliopatria polity mapping</td>
#       <td id="T_3ff09_row14_col1" class="data row14 col1" >5,700,843</td>
#       <td id="T_3ff09_row14_col2" class="data row14 col2" >43.8</td>
#     </tr>
#   </tbody>
# </table>
